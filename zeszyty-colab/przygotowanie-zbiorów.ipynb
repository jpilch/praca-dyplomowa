# %%
PROJECT_PATH = '/content/drive/MyDrive/YOLOv4'
# %cd /content/
# !rm -rf /content/sample_data/
# !rm -rf /content/OIDv4_ToolKit
# Out:
# /content

# %%
# !git clone https://github.com/EscVM/OIDv4_ToolKit.git
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 422, done.
# remote: Total 422 (delta 0), reused 0 (delta 0), pack-reused 422
# Receiving objects: 100% (422/422), 34.08 MiB | 33.69 MiB/s, done.
# Resolving deltas: 100% (146/146), done.

# %%
# !apt install tree
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 40.7 kB of archives.
# After this operation, 105 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tree amd64 1.7.0-5 [40.7 kB]
# Fetched 40.7 kB in 0s (173 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 155222 files and directories currently installed.)
# Preparing to unpack .../tree_1.7.0-5_amd64.deb ...
# Unpacking tree (1.7.0-5) ...
# Setting up tree (1.7.0-5) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# %cd OIDv4_ToolKit/
# Out:
# /content/OIDv4_ToolKit

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 3.8 MB 34.8 MB/s
# ...
#      |████████████████████████████████| 79 kB 8.7 MB/s
# ...
#      |████████████████████████████████| 547 kB 41.2 MB/s
# ...
#      |████████████████████████████████| 8.4 MB 36.3 MB/s
# ...
#      |████████████████████████████████| 138 kB 60.7 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.8
#     Uninstalling rsa-4.8:
#       Successfully uninstalled rsa-4.8
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.17.1
#     Uninstalling docutils-0.17.1:
#       Successfully uninstalled docutils-0.17.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !echo 'Person' > /content/OIDv4_ToolKit/classes.txt
# !cat /content/OIDv4_ToolKit/classes.txt
# Out:
# Person

# %%
# !python main.py downloader --classes Person --type_csv train --limit 10
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Person.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] y
# ...145%, 0 MB, 25830 KB/s, 0 seconds passed
# ...

# %%
# !tree -d $(pwd)
# Out:
# /content/OIDv4_ToolKit
# ├── images
# ├── modules
# │   └── __pycache__
# └── OID
#     ├── csv_folder
#     └── Dataset
#         ├── train
#         │   └── Person
#         │       └── Label
#         └── validation
#             └── Person
#                 └── Label
#
# 12 directories

# %%
# !python main.py downloader --classes Person --type_csv validation --limit 4
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Person.
#    [ERROR] | Missing the validation-annotations-bbox.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] y
# ...100%, 16 MB, 33375 KB/s, 0 seconds passed
# ...

# %%
# !tree -d $PROJECT_PATH
# Out:
# /content/drive/MyDrive/YOLOv4
# ├── detektor
# │   └── wagi
# ├── skrypty
# └── wideo
#     ├── logi
#     ├── referencyjne
#     ├── skompresowane
#     └── wyniki
#
# 8 directories

# %%
# !python $PROJECT_PATH/skrypty/convert_to_yolo_format.py
# Out:
# 100% 400/400 [00:12<00:00, 31.23it/s]
# 100% 1200/1200 [01:20<00:00, 14.84it/s]

# %%
# !mv -v OID/Dataset/train/Person OID/Dataset/train/train 
# !mv -v OID/Dataset/validation/Person OID/Dataset/validation/validate
# Out:
# renamed 'OID/Dataset/train/Person' -> 'OID/Dataset/train/train'
# renamed 'OID/Dataset/validation/Person' -> 'OID/Dataset/validation/validate'

# %%
# !rm -rf OID/Dataset/train/Person/Label
# !rm -rf OID/Dataset/validation/Person/Label

# %%
# !tree -d /content/OIDv4_ToolKit
# Out:
# /content/OIDv4_ToolKit
# ├── images
# ├── modules
# │   └── __pycache__
# └── OID
#     ├── csv_folder
#     └── Dataset
#         ├── train
#         │   └── train
#         └── validation
#             └── validate
#
# 10 directories

# %%
# !zip -r /content/train.zip OID/Dataset/train/train
# !zip -r /content/validate.zip OID/Dataset/validation/validate

# %%
# !cp -v /content/*.zip $PROJECT_PATH/detektor/
# Out:
# '/content/train.zip' -> '/content/drive/MyDrive/YOLOv4/detektor/train.zip'
# '/content/validate.zip' -> '/content/drive/MyDrive/YOLOv4/detektor/validate.zip'
